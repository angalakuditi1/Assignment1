# %% [markdown]
# Consider following code to answer further questions:
# import pandas as pd
# course_name = [‘Data Science’, ‘Machine Learning’, ‘Big Data’, ‘Data Engineer’]
# duration = [2,3,6,4]
# df = pd.DataFrame(data = {‘course_name’ : course_name, ‘duration’ : duration})

# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# %% [markdown]
# Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
df['duration']
# Out:
# 0    2
# 1    3
# 2    6
# 3    4
# Name: duration, dtype: int64

# %% [markdown]
# Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?

# %% [markdown]
# In Pandas, the difference between loc and iloc lies in how they select rows and columns:
#
# loc: Selects data by label (row or column name).
# Example: df.loc[2, 'Name'] selects the value in row with label 2 and column Name.
#
# iloc: Selects data by position (integer index).
# Example: df.iloc[2, 1] selects the value at the 3rd row and 2nd column (0-based index).

# %%
#example
new = pd.DataFrame({'name':["raghu",'raja','roja','shyam'],
                    'age' : [22,25,25,23]})

# %%
new.loc[0,'name']
# Out:
# 'raghu'

# %%
new.iloc[0]
# Out:
# name    raghu
# age        22
# Name: 0, dtype: object

# %% [markdown]
# Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df
# then find the output for both new_df.loc[2] and new_df.iloc[2].
# Did you observe any difference in both the outputs? If so then explain it.

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.461374  0.579177  0.818363  0.358567  0.176206  0.377059
# 2  0.329497  0.240948  0.163697  0.589273  0.106575  0.107121
# 3  0.681507  0.965710  0.482332  0.804084  0.591701  0.017520
# 4  0.292845  0.293933  0.578528  0.824233  0.388186  0.515761
# 5  0.561045  0.539627  0.442887  0.793787  0.049171  0.032745
# 6  0.072728  0.328877  0.837175  0.608232  0.041995  0.709167

# %%
new_df = df1.reindex([3,0,1,2])

# %%
new_df
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 3  0.681507  0.965710  0.482332  0.804084  0.591701  0.017520
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1  0.461374  0.579177  0.818363  0.358567  0.176206  0.377059
# 2  0.329497  0.240948  0.163697  0.589273  0.106575  0.107121

# %%
new_df.loc[2]
# Out:
# column_1    0.329497
# column_2    0.240948
# column_3    0.163697
# column_4    0.589273
# column_5    0.106575
# column_6    0.107121
# Name: 2, dtype: float64

# %%
new_df.iloc[2]
# Out:
# column_1    0.461374
# column_2    0.579177
# column_3    0.818363
# column_4    0.358567
# column_5    0.176206
# column_6    0.377059
# Name: 1, dtype: float64

# %% [markdown]
# the main difference is that in loc[] the it went for the row where the index is 2 and where as iloc[] it went for the exact index number of that position

# %% [markdown]
# Q4. Write a code to find the following statistical measurements for the above dataframe df1:
# (i) mean of each and every column present in the dataframe.
# (ii) standard deviation of column, ‘column_2’

# %%
df1.describe()
# Out:
#        column_1  column_2  column_3  column_4  column_5  column_6
# count  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   0.399833  0.491379  0.553830  0.663029  0.225639  0.293229
# std    0.215642  0.269493  0.253178  0.181174  0.219959  0.285677
# min    0.072728  0.240948  0.163697  0.358567  0.041995  0.017520
# 25%    0.302008  0.302669  0.452749  0.594013  0.063522  0.051339
# 50%    0.395436  0.434252  0.530430  0.701009  0.141390  0.242090
# 75%    0.536127  0.569290  0.758404  0.801510  0.335191  0.481086
# max    0.681507  0.965710  0.837175  0.824233  0.591701  0.709167

# %%
df1.mean()
# Out:
# column_1    0.399833
# column_2    0.491379
# column_3    0.553830
# column_4    0.663029
# column_5    0.225639
# column_6    0.293229
# dtype: float64

# %%
df1[['column_1','column_2']].std()
# Out:
# column_1    0.215642
# column_2    0.269493
# dtype: float64

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.461374  0.579177  0.818363  0.358567  0.176206  0.377059
# 2  0.329497  0.240948  0.163697  0.589273  0.106575  0.107121
# 3  0.681507  0.965710  0.482332  0.804084  0.591701  0.017520
# 4  0.292845  0.293933  0.578528  0.824233  0.388186  0.515761
# 5  0.561045  0.539627  0.442887  0.793787  0.049171  0.032745
# 6  0.072728  0.328877  0.837175  0.608232  0.041995  0.709167

# %% [markdown]
# Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the
# mean of column, column_2.
# If you are getting errors in executing it then explain why.
# [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
df1.iloc[1,0:2] = 'raghu'
# Out:
# C:\Users\benha\AppData\Local\Temp\ipykernel_6328\1568860388.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'raghu' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df1.iloc[1,0:2] = 'raghu'
# C:\Users\benha\AppData\Local\Temp\ipykernel_6328\1568860388.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'raghu' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df1.iloc[1,0:2] = 'raghu'

# %%
pw = df1[['column_1','column_2']].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 pw = df1[['column_1','column_2']].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %% [markdown]
# the error is the unsupported operand type

# %% [markdown]
# Q6. What do you understand about the windows function in pandas and list the types of windows
# functions?

# %% [markdown]
# In Pandas, window functions are used for performing operations over a "window" of values in a data series. These functions are particularly useful for analyzing time series data, statistical computations, and smoothening or aggregating over rolling or expanding windows.
#
# A window in Pandas refers to a subset of rows defined by certain criteria. For example, a rolling window of size 3 considers three consecutive rows at a time.Perform aggregations like sum, mean, or min/max over a defined window.Compute statistics like variance or standard deviation within the window.Smooth data, such as using moving averages.

# %% [markdown]
# Q7. Write a code to print only the current month and year at the time of answering this question.
# [Hint: Use pandas.datetime function]

# %%
current = pd.Timestamp.now()

# %%
current
# Out:
# Timestamp('2025-01-09 00:42:59.837585')

# %%
current.month
# Out:
# 1

# %%
current.year
# Out:
# 2025

# %% [markdown]
# Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and
# calculates the difference between them in days, hours, and minutes using Pandas time delta. The
# program should prompt the user to enter the dates and display the result.

# %%
import pandas as pd


date1 = input("Enter the first date : ")
date2 = input("Enter the second date: ")


date1 = pd.to_datetime(date1)
date2 = pd.to_datetime(date2)

delta = date2 - date1

days = delta.days
hours = delta.seconds // 3600  
minutes = (delta.seconds % 3600) // 60 

print(f"The difference between the two dates is {days} days, {hours} hours, and {minutes} minutes.")
# Out:
# Enter the first date :  12-12-2023
# Enter the second date:  15-11-2024
# The difference between the two dates is 339 days, 0 hours, and 0 minutes.
# C:\Users\benha\AppData\Local\Temp\ipykernel_16920\1828520676.py:9: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   date2 = pd.to_datetime(date2)

# %% [markdown]
# Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified
# column to a categorical data type. The program should prompt the user to enter the file path, columnname, and category order, and then display the sorted data.

# %%
import pandas as pd
def sorting_items(file_path,col_name,category_order):
    nw = pd.read_csv(file_path)
    nw[col_name] = pd.Categorical(nw[col_name],categories =category_order,ordered = True)
    vw = nw.sort_values(by=col_name)
    return vw

# %%
sorting_items('movie.csv','movie3',['mr perfect','chakram'])
# Out:
#         movie1    movie2      movie3  order
# 1  chatrapathi   darling  mr perfect      2
# 0      varsham  pournami     chakram      1

# %% [markdown]
# Q10. Write a Python program that reads a CSV file containing sales data for different products and
# visualizes the data using a stacked bar chart to show the sales of each product category over time. The
# program should prompt the user to enter the file path and display the chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt


def show_chart(file_path):
    nw = pd.read_csv(file_path)
    nw = pd.DataFrame(nw)
    nw.plot(kind = 'bar',stacked = True)
    plt.xlabel('MONTHS')
    plt.ylabel('SALES')
    plt.show()

file_path = input('please enter the file path')
show_chart(file_path)
# Out:
# please enter the file path sales.csv

# %% [markdown]
# Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write
# a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and
# displays the results in a table.
# The program should do the followingM
# I Prompt the user to enter the file path of the CSV file containing the student dataR
# I Read the CSV file into a Pandas DataFrameR
# I Calculate the mean, median, and mode of the test scores using Pandas toolsR
# I Display the mean, median, and mode in a table.
# Assume the CSV file contains the following columnsM
# I Student ID: The ID of the studentR
# I Test Score: The score of the student's test.
# Example usage of the program:
# Enter the file path of the CSV file containing the student data: student_data.csv
# +-----------+--------+
# | Statistic | Value |
# +-----------+--------+
# | Mean | 79.6 |
# | Median | 82 |
# | Mode | 85, 90 |
# +-----------+--------+
# Assume that the CSV file student_data.csv contains the following data:
# Student ID,Test Score
# 1,85
# 2,90
# 3,80
# 4,75
# 5,85
# 6,82
# 7,78
# 8,85
# 9,90
# 10,85
# The program should calculate

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def student_statistics(file_path):
        df = pd.read_csv(file_path)
        print("DataFrame of the CSV File")
        print(df)
        meann = df['Test Score'].mean()
        mediann = df['Test Score'].median()
        modee = df['Test Score'].mode()[0]
        print("+-----------+--------+")
        print("| Statistic | Value |")
        print("+-----------+--------+")
        print(f"| Mean     | {meann} |")
        print(f"| Median   | {mediann} |")
        print(f"| Mode     | {modee} |")
        print("+-----------+--------+")

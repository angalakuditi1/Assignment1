# %% [markdown]
# Q1. What is a time series, and what are some common applications of time series analysis?

# %% [raw]
# A time series is a sequence of data points collected or recorded at specific time intervals, like daily, monthly, or yearly. Think of it like a chart showing how something changes over time—such as temperature, stock prices, or sales. Time series analysis is the study of these changes to understand patterns like trends, seasonality, or cycles.
#
# Common applications include predicting future values (forecasting), analyzing stock markets, monitoring weather changes, managing inventory, and tracking website traffic. It helps businesses and researchers make informed decisions based on past behavior and trends over time. Essentially, it turns time-based data into useful insights.

# %% [markdown]
# Q2. What are some common time series patterns, and how can they be identified and interpreted?

# %% [raw]
# Common time series patterns include trend, seasonality, cyclicity, and irregular variations.
#
# Trend refers to the long-term upward or downward movement in data over time. It can be identified using moving averages or line plots.
#
# Seasonality is a repeating pattern at regular intervals, like daily, monthly, or yearly. It’s detected through visual plots or autocorrelation functions (ACF).
#
# Cyclic patterns occur over irregular intervals, often influenced by economic or business cycles. These can be spotted using smoothing techniques or decomposition.
#
# Irregular (residual) components are random, unpredictable variations. These are identified after removing trend and seasonal components.
#
# Interpreting these patterns helps in understanding the underlying behavior of the data. For example, strong seasonality may indicate high sales during festivals, while a trend can show overall business growth. Recognizing these patterns is key for accurate forecasting and decision-making in domains like finance, weather, and sales analysis.

# %% [markdown]
# Q3. How can time series data be preprocessed before applying analysis techniques?

# %% [raw]
# To preprocess time series data, start by organizing the data in date and time order. Make sure there are no missing timestamps or values; if any are missing, fill them using techniques like forward filling or averaging. Next, check for outliers—sudden spikes or drops that don't make sense—and fix or remove them. Then, convert the time column into a standard datetime format. You may also need to resample the data (e.g., convert daily data to weekly) for better analysis. Normalize or scale the values if they vary widely. Lastly, create new time-based features like day, month, or season if needed. These steps help make the data clean and ready for accurate analysis or modeling.

# %% [markdown]
# Q4. How can time series forecasting be used in business decision-making, and what are some common
# challenges and limitations?

# %% [raw]
# Time series forecasting helps businesses predict future values based on past data, like sales, demand, or website traffic. For example, a shop can estimate how many ice creams to stock next summer by looking at previous years’ sales. This helps in planning, budgeting, and avoiding overstock or shortages.
#
# However, it’s not perfect. Forecasts can go wrong if there's sudden change—like a new competitor, economic crisis, or unexpected weather. Also, the method assumes past patterns will repeat, which may not always be true. It requires clean, consistent data, and choosing the right model can be tricky. Short-term predictions are usually more accurate than long-term ones.
#
# In short, while time series forecasting supports smarter decisions, it’s important to understand its limits and not rely on it alone.

# %% [markdown]
# Q5. What is ARIMA modelling, and how can it be used to forecast time series data?

# %% [raw]
# ARIMA (AutoRegressive Integrated Moving Average) is a popular method used to forecast time series data — data collected over time like stock prices, sales, or temperature.
#
# In simple terms, ARIMA looks at patterns in past data to predict future values. It has three main parts:
#
# AR (AutoRegressive): It uses past values to predict the future. Like saying, “If sales were high last month, they might be high this month too.”
#
# I (Integrated): It makes the data stable by removing trends. For example, if sales are growing over time, this step helps flatten it.
#
# MA (Moving Average): It looks at past errors (differences between predicted and actual values) to correct future predictions.
#
# ARIMA is powerful because it combines these ideas to make accurate forecasts. It’s widely used in business and economics to plan ahead using historical data. However, ARIMA works best with consistent and structured data.

# %% [markdown]
# Q6. How do Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF) plots help in
# identifying the order of ARIMA models?

# %% [raw]
# In simple terms, ACF and PACF plots help us decide how many past values (lags) we should include in an ARIMA model.
#
# ACF (Autocorrelation Function) shows how strongly current values are related to past values. If the ACF plot shows a slow decrease (decay), it suggests the data is not stationary and might need differencing (the "I" in ARIMA).
#
# PACF (Partial Autocorrelation Function) helps identify how many lag terms to include in the AR (Auto-Regressive) part. We look for where the PACF suddenly drops or cuts off — that’s our AR order.
#
# Once the data is stationary, we use ACF to decide the MA (Moving Average) part by looking where it cuts off.
#
# Together, these plots guide us to pick the right ARIMA model order (p, d, q).

# %% [markdown]
# Q7. What are the assumptions of ARIMA models, and how can they be tested for in practice?

# %% [raw]
# ARIMA models assume your data’s pattern stays mostly the same over time, like no big changes in average or how spread out it is. They also assume past data and past mistakes help predict the future. The leftover errors after the model tries to predict should look like random noise — no clear patterns.
#
# To check this, we look at graphs and do a test called ADF to see if the data’s pattern is steady. If not, we can fix it by subtracting previous values (called differencing).
#
# Then, we check the errors to make sure they don’t have patterns using a test called Ljung-Box and look at charts to see if errors follow a normal pattern.
#
# Doing these checks helps the ARIMA model give better predictions.

# %% [markdown]
# Q8. Suppose you have monthly sales data for a retail store for the past three years. Which type of time
# series model would you recommend for forecasting future sales, and why?

# %% [raw]
# For forecasting monthly sales data over the past three years, I would recommend using an ARIMA model or a Seasonal ARIMA (SARIMA) model.
#
# Here’s why in simple terms:
#
# Sales data often have patterns that repeat every year, like higher sales during holidays or festivals. This is called seasonality. Besides that, sales might gradually increase or decrease over time, which is called a trend. An ARIMA model helps capture trends and past sales patterns to predict the future. When seasonality is strong (like monthly data showing yearly cycles), SARIMA is better because it explicitly includes seasonal patterns.
#
# Using these models helps the store understand how sales change over time and during different months, making forecasts more accurate. This helps in planning inventory, staffing, and promotions.
#
# So, ARIMA or SARIMA models are great because they handle both trends and seasonal effects in sales data clearly and effectively.

# %% [markdown]
# Q9. What are some of the limitations of time series analysis? Provide an example of a scenario where the
# limitations of time series analysis may be particularly relevant.

# %% [raw]
# Time series analysis studies data collected over time to find patterns and make predictions. But it has some limitations. First, it assumes the past patterns will continue, which might not happen if sudden changes occur, like a new technology or a natural disaster. Second, it needs a lot of historical data to be accurate, which may not always be available. Third, it can be affected by noise or random fluctuations in the data, making predictions less reliable.
#
# For example, predicting sales for a store during a pandemic is hard. Past sales data won’t show the unusual drop or surge because the pandemic changed customer behavior drastically. So, time series analysis might fail to give correct predictions in such unpredictable situations.

# %% [markdown]
# Q10. Explain the difference between a stationary and non-stationary time series. How does the stationarity
# of a time series affect the choice of forecasting model?

# %% [raw]
# In simple terms, a stationary time series has a constant average, constant variance (spread of data), and does not change its behavior over time. Think of it like the heartbeat of a calm person — steady and predictable. On the other hand, a non-stationary time series has trends, seasonality, or changing patterns over time — like someone running, whose heartbeat keeps changing.
#
# Why it matters: Many forecasting models, like ARIMA, work best when the data is stationary because it's easier to identify consistent patterns and relationships. If the data is non-stationary, these models may give poor results. So, before forecasting, we often transform non-stationary data into stationary (using methods like differencing or log transformation).
#
# In short, knowing whether your data is stationary helps choose the right forecasting model and improves accuracy. Treating non-stationary data properly is like cleaning the lens before taking a photo — you get a clearer view.

# %% [markdown]
# Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with
# an example.

# %% [raw]
# 1. Probability Mass Function (PMF):
# PMF is used for discrete random variables,It gives the probability of a discrete random variable taking on a specific value,The sum of all probabilities over all possible values is equal to 1.
# Example of PMF:
# Suppose a fair six-sided die is rolled. Let X be the random variable representing the outcome of the roll.
# X can take discrete values {1,2,3,4,5,6}.
#
# 2. Probability Density Function (PDF):
# PDF is used for continuous random variables,Unlike PMF, PDF does not give the probability of the random variable taking a specific value. Instead, it represents the probability density.The probability of the random variable lying within an interval
# [𝑎,𝑏] is given by the area under the curve of the PDF between

# %% [markdown]
# Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?

# %% [raw]
# Cumulative Density Function (CDF)
# The Cumulative Density Function (CDF) of a random variable is a function that gives the probability that the random variable will take a value less than or equal to a given value. In other words, the CDF at 𝑥 is the probability that the random variable X is less than or equal to x.
#
# Properties of CDF
#
# Non-decreasing: The CDF is always non-decreasing (it either increases or remains constant).
# Right-continuous: The CDF is continuous from the right.

# %% [markdown]
# Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.

# %% [raw]
# The normal distribution is widely used in statistics to model real-world phenomena due to its symmetric bell-shaped curve. Here are some examples where it might be applicable:
#
# Human characteristics: Heights, weights, and IQ scores of a population often follow a normal distribution, Errors in scientific measurements or instrument readings tend to be normally distributed,Daily stock price changes or returns on investments approximate a normal distribution under stable market conditions.,When no skewed external factors are present, scores from standardized tests typically follow a normal distribution,Data like blood pressure, temperatures, and certain biological measurements often align with a normal distribution.
#
# Relationship Between Parameters and Shape:
#
# The normal distribution is defined by two parameters: mean (μ) and standard deviation (σ).
#
# Mean (μ): The mean determines the center of the distribution. It represents the point of symmetry and the peak of the curve. Shifting μ changes the position of the curve along the horizontal axis without affecting its shape.
#
# Standard Deviation (σ): The standard deviation determines the spread or width of the curve. A smaller σ results in a narrower, taller curve, while a larger σ creates a wider, flatter curve. Approximately 68%, 95%, and 99.7% of the data lie within 1σ, 2σ, and 3σ from the mean, respectively.
#
# In summary, the mean influences the position of the curve, and the standard deviation dictates how spread out or concentrated the data is around the mean. Together, these parameters define the distribution's shape, helping model real-world phenomena effectively.

# %% [markdown]
# Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal
# Distribution.

# %% [raw]
# The Normal Distribution, also known as the bell curve, is crucial in statistics because it describes how data points are spread out or distributed around the average. In many cases, the distribution of data in nature, society, and business tends to follow this bell-shaped curve, where most values are close to the mean and fewer values lie at the extremes.
#
# Here’s why the Normal Distribution is important:
#
# Predictability: It helps in making predictions about probabilities, such as the likelihood of a certain outcome, because many natural phenomena follow this distribution.
#
# Standardization: It allows for comparison across different datasets and makes it easier to understand data with common metrics like the mean, median, and standard deviation.
#
# Statistical Analysis: It forms the foundation of many statistical tests and procedures. When we assume data follows a Normal Distribution, we can apply certain statistical tools to understand and predict trends.
#
# Real-life Examples:
# Height of People: In a large group of people, most will have a height close to the average height (mean), with fewer individuals being very short or very tall. The distribution of heights in a population tends to follow a Normal Distribution.

# %% [markdown]
# Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli
# Distribution and Binomial Distribution?

# %% [raw]
# Bernoulli Distribution
#
# The Bernoulli Distribution is a discrete probability distribution that models a random experiment with only two possible outcomes: success (1) and failure (0). It is defined by a single parameter, p, which represents the probability of success. The probability of failure is 1-p.
#
# The probability mass function (PMF) of a Bernoulli Distribution is:
#
# 𝑃(𝑋=1)= 𝑝
# P(X=0)=1−p
# It is commonly used in situations where there is a single trial or experiment.
# Example:
# Tossing a coin once: Let "Heads" be success (p=0.5) and "Tails" be failure (1−p=0.5).
#
# Binomial Distribution
#
# The Binomial Distribution is an extension of the Bernoulli Distribution, used to model the number of successes in n independent Bernoulli trials. It is defined by two parameters: n (number of trials) and p (probability of success in each trial).Example:
# Tossing a coin 10 times and counting the number of Heads (n=10,p=0.5).

# %% [markdown]
# Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset
# is normally distributed, what is the probability that a randomly selected observation will be greater
# than 60? Use the appropriate formula and show your calculations.

# %%
import scipy.stats as stats

mean = 50
std_dev = 10
X = 60

z_score = (X - mean) / std_dev


p_greater_than_60  = 1 - stats.norm.cdf(z_score)

print(p_greater_than_60)
# Out:
# 0.15865525393145707

# %% [markdown]
# Q7: Explain uniform Distribution with an example.

# %% [raw]
# Uniform distribution is a type of probability distribution where every outcome in a specified range has an equal chance of occurring. It can be classified into two types: discrete uniform distribution and continuous uniform distribution.
#
# Discrete Uniform Distribution:
#
# In a discrete uniform distribution, the outcomes are countable, and each one has the same probability. A common example is a fair die roll. When you roll a six-sided die, the outcomes are 1, 2, 3, 4, 5, and 6. Each of these outcomes has an equal chance of occurring, which means the probability of rolling any particular number is
# 1,6,6,1
# ​
#
# Continuous Uniform Distribution:
# In a continuous uniform distribution, the outcomes form a continuous range, and each value within this range is equally likely. For example, if you randomly select a number between 0 and 10, the probability of choosing any specific number is the same as choosing any other number within this interval. The probability density function (PDF) for continuous uniform distribution between
#
# In both cases, the probability is uniformly distributed across the range, meaning all outcomes are equally likely.

# %% [markdown]
# Q8: What is the z score? State the importance of the z score.

# %% [raw]
# he Z-score, also known as the standard score, measures how many standard deviations a particular data point is from the mean of a data set. It is calculated using the formula:
#
# 𝑍= 𝑋 − 𝜇/𝜎
#
# Where:
#
# X is the data point,μ is the mean of the data set,σ is the standard deviation.
# The Z-score tells you whether a data point is below or above the mean and by how much. A Z-score of 0 indicates that the data point is exactly at the mean. Positive Z-scores indicate values above the mean, and negative Z-scores indicate values below the mean.
#
# Importance of Z-Score:
# Standardization: Z-scores allow you to compare data points from different distributions or units by standardizing them to a common scale. This is particularly useful when working with different datasets.
#
# Outlier Detection: Z-scores help identify outliers in data. A Z-score greater than 3 or less than -3 typically indicates an outlier.
#
# Probability and Hypothesis Testing: In normal distributions, Z-scores are used to calculate probabilities and perform hypothesis testing, helping in decision-making.
#
# Data Interpretation: Z-scores provide context to raw data, helping to understand how extreme or typical a particular value is within the dataset.

# %% [raw]
# Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.

# %% [raw]
# The Central Limit Theorem (CLT) is a fundamental principle in statistics that states that, regardless of the population's distribution, the distribution of the sample mean approaches a normal (Gaussian) distribution as the sample size increases, provided the samples are independent and identically distributed
# ​
# Significance:
# Normal Approximation: The CLT lets us approximate sample means as normally distributed, which simplifies statistical analysis.
#
# Statistical Inference: It forms the basis for hypothesis testing and confidence intervals, enabling inference about populations from sample data.
#
# Simplifies Analysis: By relying on normal distribution properties, the CLT simplifies complex statistical calculations.
#
# Foundation for Statistical Methods: Many techniques, such as z-tests and t-tests, depend on the assumption of normally distributed sample means.
# In essence, the CLT is key to many statistical methods, enabling reliable conclusions from sample data.

# %% [markdown]
# Q10: State the assumptions of the Central Limit Theorem.

# %% [raw]
# The Central Limit Theorem (CLT) has the following key assumptions:
#
# Independence: The observations in the sample must be independent of each other. This means that the value of one observation does not influence the value of another.
#
# Sample Size: For the CLT to hold, the sample size should be sufficiently large. Typically, a sample size of 30 or more is considered large enough, though this may vary depending on the underlying population distribution.
#
# Identically Distributed: The data points in the population must come from the same distribution, although this distribution can be any shape (normal or non-normal).
#
# Finite Mean and Variance: The population from which the sample is drawn must have a finite mean (µ) and finite variance (σ²). If the variance is infinite, the CLT does not apply.
#
# Random Sampling: The samples must be randomly selected, ensuring that each sample has an equal chance of being chosen.
#
# The CLT states that, given these assumptions, the distribution of the sample mean will approach a normal distribution as the sample size increases, regardless of the shape of the population distribution.

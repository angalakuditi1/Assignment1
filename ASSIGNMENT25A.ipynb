# %% [markdown]
# Q1. Describe the decision tree classifier algorithm and how it works to make predictions.

# %% [raw]
# A Decision Tree Classifier is like a flowchart that helps make decisions based on questions. It starts with a main question at the top (root), then branches out based on answers (yes/no or other values). Each step checks one feature (like age, income, etc.) and moves down the tree until it reaches a final decision (like "yes" or "no"). It's like playing 20 Questions to find the answer. The tree is built using training data, learning which questions give the best splits. When given new data, it follows the same path to predict the result

# %% [markdown]
# Q2. Provide a step-by-step explanation of the mathematical intuition behind decision tree classification.

# %% [raw]
# Goal: Classify data by asking yes/no questions—like "Is age > 30?"—to split data into groups.
#
# Start at the root: Begin with all data. Pick the best question (feature + value) to split it.
#
# How to choose?: Use Gini Impurity or Entropy to measure how "mixed" a group is. A pure group (all same class) is best.
#
# Split wisely: For every feature, calculate how much impurity decreases after a split (called information gain).
#
# Pick the best: Choose the feature that gives the highest gain—the best split.
#
# Repeat: Keep splitting each new group using the same idea until:
#
# All items are pure, or A stopping rule is met (like max depth or few samples left).
# Prediction: To classify new data, follow the tree path based on answers to feature questions.

# %% [markdown]
# Q3. Explain how a decision tree classifier can be used to solve a binary classification problem.

# %% [raw]
# A Decision Tree Classifier solves a binary classification problem by acting like a flowchart or a series of "yes" or "no" questions. Imagine you're trying to decide if an email is spam or not spam. The decision tree starts with a simple question, like “Does the email contain the word ‘free’?” Based on the answer (yes or no), it moves down a branch to the next question, such as “Is there a link in the email?” This process continues until it reaches a final decision—spam or not spam.
#
# Each question is based on features (like words or numbers) that help split the data best. The goal is to separate the data step by step until it's clearly in one group or the other. This makes decision trees easy to understand and useful for tasks like medical diagnoses, loan approvals, or spam detection in emails—where the answer is either yes or no.

# %% [markdown]
# Q4. Discuss the geometric intuition behind decision tree classification and how it can be used to make
# predictions.

# %% [raw]
# A decision tree is like playing a game of 20 Questions to guess something. Imagine you're trying to guess an object by asking simple yes/no questions like "Is it bigger than a football?" or "Is it made of metal?"—each question splits the possibilities in half.
#
# In decision tree classification, the model asks questions about the features of data (like age, income, etc.), and at each step, it splits the data into smaller groups. These splits create boundaries in space—like drawing straight lines to divide regions. Each region ends in a “leaf” that gives a final prediction or class label.
#
# Geometrically, this is like cutting space into rectangles or boxes where each box represents a different outcome. When new data comes in, the tree checks which box it fits into, based on the same questions, and makes a prediction accordingly.

# %% [markdown]
# Q5. Define the confusion matrix and describe how it can be used to evaluate the performance of a
# classification model.

# %% [raw]
# A confusion matrix is a simple table used to measure how well a classification model is performing. Imagine a model that predicts whether an email is spam or not spam. The confusion matrix shows four numbers:
#
# True Positives (TP): Correctly predicted spam emails.
#
# True Negatives (TN): Correctly predicted not-spam emails.
#
# False Positives (FP): Emails wrongly marked as spam.
#
# False Negatives (FN): Spam emails wrongly marked as not spam.
#
# This matrix helps us understand not just how many predictions were right, but what kind of mistakes the model made. For example, a model might get 95 out of 100 predictions right, but if most of its mistakes are false negatives (missing real spam), that's a big problem. Using the confusion matrix, we can calculate accuracy, precision, recall, and F1-score, which give a fuller picture of the model's performance than just accuracy alone.

# %% [markdown]
# Q6. Provide an example of a confusion matrix and explain how precision, recall, and F1 score can be
# calculated from it.

# %% [raw]
# Imagine a hospital uses a model to detect COVID-19 in 100 patients. Out of these, 50 actually have COVID, and 50 don’t. The model predicts:
#
# 40 true positives (correctly says COVID+)
#
# 10 false negatives (misses actual COVID cases)
#
# 5 false positives (wrongly says healthy people have COVID)
#
# 45 true negatives (correctly says COVID-)
#
# Precision = TP / (TP + FP) = 40 / (40+5) = 88.9%
# It means when the model says someone is COVID+, it's right 89% of the time.
#
# Recall = TP / (TP + FN) = 40 / (40+10) = 80%
# Out of all real COVID cases, the model catches 80%.
#
# F1 Score is the balance:
# F1 = 2 × (Precision × Recall) / (Precision + Recall) ≈ 84.2%
#
# So, the model is fairly reliable but still misses some cases, which is risky in medical situations.

# %% [markdown]
# Q7. Discuss the importance of choosing an appropriate evaluation metric for a classification problem and
# explain how this can be done.

# %% [raw]
# Choosing the right evaluation metric in a classification problem is like picking the right tool to measure success. For example, accuracy might look good, but if one class dominates, it can be misleading. Instead, metrics like precision, recall, or F1-score help us understand how well the model performs for each class, especially in cases like disease detection or fraud detection. The best metric depends on what matters more—catching all positives (recall) or being correct when saying something is positive (precision). Always choose the metric based on the problem’s real-world impact and the balance between errors.

# %% [markdown]
# Q8. Provide an example of a classification problem where precision is the most important metric, and
# explain why.

# %% [raw]
# Example: An email spam filter.
#
# Why Precision Matters:
# In this case, precision is more important because we want to be very sure when labeling an email as spam. If the filter wrongly marks an important email (like a job offer or a bank message) as spam, the user might miss it completely. That’s a big problem. So, it’s better to only mark emails as spam when we're confident. In simple terms, precision helps us avoid false alarms—we don’t want to wrongly call good emails as spam. It's okay if a few spam emails slip through, but not okay to lose important ones.

# %% [markdown]
# Q9. Provide an example of a classification problem where recall is the most important metric, and explain
# why.

# %% [raw]
# Example: Detecting cancer in medical tests.
#
# Explanation (Layman, 100 words):
# In cancer detection, recall is very important because it tells us how many actual cancer cases we successfully found. Missing a cancer patient (false negative) can be life-threatening, while wrongly saying someone has cancer (false positive) can be corrected with further tests. So, we care more about catching all real cancer cases even if we make some mistakes along the way. That’s why recall matters more here—it helps ensure we don't leave out someone who truly needs treatment. In simple terms, it’s better to be safe than sorry when it comes to health.

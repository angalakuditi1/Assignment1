# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Flask is a lightweight, web framework for Python that allows developers to build web applications quickly and easily. It is classified as a micro-framework, meaning it provides the essential tools for web development but does not include built-in functionalities like form validation, database abstraction, or authentication out of the box.Flask is often used for building small to medium-sized applications, APIs, and prototypes, but it is flexible enough for more complex systems as well.
#
# the main advantage of using flask is Lightweight and Simple,Flexible and Extensible,Flask has extensive and clear documentation that makes it easy for both beginners and experienced developers to get started quickly,Flask comes with a built-in development server that makes it easy to test and debug applications locally.}|

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hi():
    return "Hello World!"

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Nov/2024 22:26:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Nov/2024 22:26:27] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# ![Screenshot (27).png](attachment:ddbeb892-7d11-41f0-a8da-66cd40eb1e14.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
#
# App routing in Flask is the process of mapping URLs to specific functions in your application. Routes define the paths that users can visit, and each route is associated with a function  that handles the logic for that URL.
# it needed for Define URL paths,Map URLs to functions,Dynamic handling.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hi():
    return """Company Name: ABC Corporation
              Location: India
              Contact Detail: 999-999-9999"""

@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation"

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Nov/2024 23:16:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Nov/2024 23:16:49] "GET /welcome HTTP/1.1" 200 -

# %% [markdown]
# ![Screenshot (29).png](attachment:67a096af-a20d-40ec-9ef7-eefa6fcb6dda.png)![Screenshot (28).png](attachment:ec889a22-054d-45d6-b255-b071df68a579.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
#
# In Flask, the url_for() function is used for URL building. It generates a URL for a given endpoint, which can be useful when you need to dynamically create URLs for routes in your application.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'Home Page'

@app.route('/about')
def about():
    return 'About Page'

@app.route('/url_test')
def url_test():
    # Using url_for to generate the URL for the 'about' endpoint
    about_url = url_for('about')
    return f'URL for About page: {about_url}'

if __name__ == '__main__':
    app.run(debug=True)

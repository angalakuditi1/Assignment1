# %% [markdown]
# Q1. What is Bayes' theorem?

# %% [raw]
# Bayes' theorem is a way to update our beliefs about something based on new evidence. Imagine you’re trying to figure out if someone has a cold. You already have an idea of how likely it is that they have a cold, based on things like the season or if they’ve been near sick people. But then, you get new evidence, like them sneezing or coughing. Bayes’ theorem helps you combine your initial belief with this new evidence to get a better idea of whether they actually have a cold or not.
#
# In simple terms, Bayes’ theorem provides a formula for updating probabilities when we learn new information. It combines the prior probability (what we believed before) with the likelihood of the evidence given that belief, to calculate the posterior probability (what we should believe after seeing the evidence). It's widely used in statistics, machine learning, and decision-making.

# %% [markdown]
# Q2. What is the formula for Bayes' theorem?

# %% [raw]
# P(A|B) = (P(B|A) * P(A)) / P(B)
#
# Where:
#
# P(A|B) represents the conditional probability of event A occurring given that event B has occurred. This is the probability we want to calculate.
# P(B|A) is the conditional probability of event B occurring given that event A has occurred.
# P(A) is the prior probability of event A occurring independently of any information about event B.
# P(B) is the prior probability of event B occurring independently of any information about event A.

# %% [markdown]
# Q3. How is Bayes' theorem used in practice?

# %% [raw]
# Bayes' Theorem is a mathematical formula used to update the probability of an event based on new evidence. In practice, it helps us make better decisions by considering both prior knowledge and new information.
#
# For example, imagine a doctor trying to diagnose a disease. Bayes' Theorem helps the doctor combine the likelihood of the disease (prior probability) with test results (new evidence). If the test is positive, the doctor updates the chances of the patient having the disease, considering how common the disease is and how reliable the test is.
#
# In everyday life, Bayes' Theorem is used in spam filters for emails. If you receive an email with certain keywords, the filter uses prior knowledge of what spam usually looks like and combines it with the new evidence (keywords in the email) to calculate the probability that it’s spam.
#
# It’s a powerful tool for making informed decisions with incomplete or uncertain information.

# %% [markdown]
# Q4. What is the relationship between Bayes' theorem and conditional probability?

# %% [markdown]
# Q6. Assignment:
# You have a dataset with two features, X1 and X2, and two possible classes, A and B. You want to use Naive
# Bayes to classify a new instance with features X1 = 3 and X2 = 4. The following table shows the frequency of
# each feature value for each class:
# Class X1=1 X1=2 X1=3 X2=1 X2=2 X2=3 X2=4
# A 3 3 4 4 3 3 3
# B 2 2 1 2 2 2 3
# Assuming equal prior probabilities for each class, which class would Naive Bayes predict the new instance
# to belong to?

# %% [raw]
# It is been given that 2 features that is x1,x2
# and the classes are A,B here, we have to find if x1=3,x2=4 added new instances then which classes it might get into using naive bayes for that we use the formula to do it
# p(A) is already given that 50% chance for the both then it would be P(A) = 0.5
# then we have to find,
# Class A:
# P(X1 = 3 | A) = 4 / (4 + 10) = 4/10 = 0.4
# P(X2 = 4 | A) = 3 / (4 + 3) = 3/10 = 0.2308
# P(X1 = 3 | B) = 1 / (1 + 2) = 1/13 = 0.2
# P(X2 = 4 | B) = 3 / (2 + 2 + 3)= 3/13  =0.3333
#
# For class A:
#
# P(A | X1 = 3, X2 = 4) = P(X1 = 3 | A) * P(X2 = 4 | A) * P(A)
#                                  = (4/10) * (3/10) * (1/2)
#                                  = 0.1224
# For class B:
#
# P(B | X1 = 3, X2 = 4) = P(X1 = 3 | B) * P(X2 = 4 | B) * P(B)
#                                  = (1/13) * (3/13) * (1/2)
#                                  = 0.07142
# The Probabilty of class Prediction is calculated as,
#
# P(A | X1 = 3, X2 = 4) = 0.1224 / (0.1224 + 0.07142)
#                                  = 0.6316* 100
#                                  = 63.16%
#
# P(B | X1 = 3, X2 = 4) = 07142 / (0.1224 + 0.07142)
#                                  = 0.3684 or 36.84%
#                                  = 36.84%
#
# Since Probability of Class A is 63.16%  which is greater then Class B of 36.84, Naive Bayes would predict that the new instance with features X1 = 3 and X2 = 4 belongs to class A.

# %% [markdown]
# Q1: Explain the following with an example:F
# C) Artificial IntelligencJ
# <) Machine Learning,
# I) Deep Learning

# %% [markdown]
# Artificial intelligence is a umbrella term for most of the machine that try to mimic our human brain like taking decision making,problem solving and learning from data. for example voice assitance like siri or alexa it understands our commands further to explain suppose i ask siri to play a soothing music as iam stressed out the siri will think of its own to best suit my requuirement and deliver the requirement.
#
# Machine learning is a subset of AI where it takes the data overtime and understand the patterns and make suggestions and imporves overtime and give output without much of explict training to it for example a netflix take data by our watchlist and make suggestions according to it.
#
# DL is a specialized subset of ML that uses neural networks, inspired by the human brain, to analyze complex data like images, speech, and large datasets.for example an x ray machine specifies about the diesease based  on the data it has recieved various data before where it learns about deep designs and patterns

# %% [markdown]
# Q2: What is supervised learning? List some examples of supervised learning.

# %% [markdown]
# Supervised Learning is a machine learning technique where the algorithm learns from a set of input-output pairs. In this type of learning, the algorithm is trained on data that includes both the input and the correct output. The model uses this data to learn patterns and relationships, so it can predict the output for new, unseen data.
# In simple terms, labeled data is like a teacher giving  the right answers during  learning process, so we can learn to make predictions on new, unlabeled data.

# %% [markdown]
# Q3: What is unsupervised learning? List some examples of unsupervised learning.

# %% [markdown]
# Unsupervised learning is a type of machine learning where the model is given data without any labels or specific instructions on what to do with it. The goal is to let the algorithm figure out patterns and relationships on its own.for example ekart websites takes the data from the customers with no input and learns from it and acts oupn it

# %% [markdown]
# Q4: What is the difference between AI, ML, DL, and DS?

# %% [markdown]
# AI is  The broad field that involves creating systems capable of performing tasks that typically require human intelligence, such as decision-making, problem-solving, and learning.
#
# ML A subset of AI focused on algorithms that allow computers to learn patterns from data without being explicitly programmed. It involves training models on data to make predictions or decisions.
#
# DL A specialized subset of ML that uses neural networks with many layers (deep neural networks) to analyze large amounts of data. It excels in tasks like image recognition, speech processing, and natural language understanding.
#
# DS  The interdisciplinary field that involves extracting insights from data using statistical methods, programming, and domain knowledge. It often combines techniques from AI, ML, and other areas to analyze and interpret complex datasets.

# %% [markdown]
# Q5: What are the main differences between supervised, unsupervised, and semi-supervised learning?

# %% [markdown]
# supervised learning
# Uses labeled data.Goal is  Make predictions or classifications.Predicting house prices based on features like size, location.
# Unsupervised Learning:
#
# unsupervised learning
# Uses unlabeled data,Goal is  Find patterns or groupings in the data.Clustering customers based on purchasing behavior.
#
# semi-supervised learning Uses a mix of labeled and unlabeled data.Goal is  Leverage small labeled data to improve learning on a large amount of unlabeled data.Example Image recognition where only a few images are labeled, but many are not.

# %% [markdown]
# Q6: What is train, test and validation split? Explain the importance of each term.

# %% [markdown]
# In machine learning, splitting data into train, test, and validation sets is crucial for building and evaluating models:
#
# Train Set: This is the largest portion of the dataset used to train the machine learning model. It helps the model learn the patterns and relationships in the data.example a cricketer learning from the coach and fellow people at ground level
#
# Test Set: This set is used to evaluate the model’s performance after training. It’s crucial for assessing how well the model generalizes to unseen data.where the cricketer is set test his ability at differenet team than the training one to test the more on peculer or outliners to train more.
#
# Validation Set: This set helps in tuning hyperparameters and preventing overfitting. It provides feedback on how the model is performing during training, allowing adjustments to be made before the final evaluation on the test set.it's like playing the real match

# %% [markdown]
# Q7: How can unsupervised learning be used in anomaly detection?

# %% [markdown]
# Unlike supervised learning unsupervised have no lables so,it has to learn patterns from its data.The idea is to identify what "normal" data looks like based on patterns, clusters, or distributions in the dataset.

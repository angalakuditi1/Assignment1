# %% [markdown]
# Q1. How do you comment code in Python? What are the different types of comments?
#
# comments in the python are mostly used for the interpretation like explaining things or adding things which python ignores,there two types of comments
#
# 1.single lin=e comments
# 2.multiline comments

# %% [markdown]
# Q2. What are variables in Python? How do you declare and assign values to variables?
#
# variable are used to store data in python where can be allocated a specific memory location so that we reuse it or modify it.in python
# variables are assigned by using assignment operator (=)

# %% [markdown]
# Q3. How do you convert one data type to another in Python?
#
# In python there is a concept called typcxasting where in using that can change one data type to another data type

# %% [markdown]
# Q4. How do you write and execute a Python script from the command line?
#
# We should write the python code in notepad or othersource then have to save it in .py format then open the command prompt and extract from the system and press enter to execute the code from command line.

# %% [markdown]
# #Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].
#
# my_list[1:3}

# %% [markdown]
# Q6. What is a complex number in mathematics, and how is it represented in Python?
#
# complex number is a combination of real and imaginary part where it is represnted as a+bi
# In python it is represented aa a+bj only difference is in math it is represented with (i) in python it is represented as (j)

# %% [markdown]
# Q7 .What is the correct way to declare a variable named age and assign the value 25 to it?
#
# age =25

# %% [markdown]
#  Q8.Declare a variable named price and assign the value 9.99 to it. What data type does this variable
# belong to?
#
#  price = 9.99,the data type of price is float data type

# %% [markdown]
# Q9.Create a variable named name and assign your full name to it as a string. How would you print the
# value of this variable

# %%
name = "angalakuditi vinay"

# %%
name
# Out:
# 'angalakuditi vinay'

# %% [markdown]
# Q10.Given the string "Hello, World!", extract the substring "World".

# %%
h = 'Hello,wolrd!'

# %%
h[6:]
# Out:
# 'wolrd!'

# %% [markdown]
# Q11.Create a variable named "is_student" and assign it a boolean value indicating whether you are
# currently a student or not.

# %%
is_student = True

# %%
if is_student is False:
    print('not a  current student at present')
else:
    print('he is a current student')
# Out:
# he is a current student

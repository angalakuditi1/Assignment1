# %% [raw]
# Q1. What is Statistics?

# %% [markdown]
# Statistics is the branch of mathematics that deals with the collection, organization, analysis, interpretation, and presentation of data. It is widely used in various fields such as business, science, social sciences, and technology to make informed decisions based on data.

# %% [raw]
# Q2. Define the different types of statistics and give an example of when each type might be used ?

# %% [raw]
# There are mainly two types of statistics namely
#
# 1.Descriptive statistics
#
# Focuses on summarizing and organizing data to understand its basic features.For example Measures of central tendency (mean, median, mode), measures of variability (range, variance, standard deviation), and visualizations (charts, graphs).
#
# 2.Inferential statistics
#
# Involves making predictions or inferences about a larger population based on a sample of data.For example Hypothesis testing, confidence intervals, regression analysis.

# %% [raw]
# Q3. What are the different types of data and how do they differ from each other? Provide an example of
# each type of data.

# %% [raw]
# Quantitative (Numerical): Data that represents numbers and can be measured.
# Example: Height of a person (170 cm), weight (65 kg).
#
# Qualitative (Categorical): Data that represents categories or labels.
# Example: Eye color (blue, brown), types of cars (SUV, Sedan).
#
# Discrete: Countable, whole numbers.
# Example: Number of children in a family (2, 3, etc.).
#
# Continuous: Measurable, can take any value within a range.
# Example: Temperature (36.5°C, 37.2°C).
#
# Nominal: Data with no inherent order.
# Example: Blood groups (A, B, O).
#
# Ordinal: Data with a meaningful order but no fixed difference between values.
# Example: Customer satisfaction levels (Poor, Good, Excellent).

# %% [raw]
# Q4. Categorise the following datasets with respect to quantitative and qualitative data types:
# (i) Grading in exam: A+, A, B+, B, C+, C, D, E
# (ii) Colour of mangoes: yellow, green, orange, red
# (iii) Height data of a class: [178.9, 179, 179.5, 176, 177.2, 178.3, 175.8,...]
# (iv) Number of mangoes exported by a farm: [500, 600, 478, 672, ...]

# %% [raw]
# Grading in exam can be ordered but cant do mathematical operations on it morever it is categorical so it is ORDINAL
# Color is a cateogorical data but, we can't do mathematical operations or even orderd it so it is NOMINAL
# Height is numerical and can do mathematical operations and o has meaning no weight so it is RATIO
# Number of mangoes exported is numerical and 0 has meaning so it is RATIO

# %% [markdown]
# Q5. Explain the concept of levels of measurement and give an example of a variable for each level.

# %% [raw]
# 1.Qualitative Data (Categorical Data)
#
# Nominal Data
# Data that represents categories or labels without any inherent order.
# Characteristics:
# No ranking or order.
# Used for classification.
# Example:
# Gender: Male, Female, Other
#
# Ordinal Data
# Data that represents categories with a meaningful order or ranking, but the intervals between ranks are not consistent or meaningful.
# Characteristics:
# Ordered but without precise differences between values.
# Example:
# Survey Ratings: Poor, Fair, Good, Excellent
#
# 2. Quantitative Data (Numerical Data)
#
# Interval Data
# Data that has meaningful differences between values but no true zero point.
# Characteristics:
# Can odered and have intervals meaning we can add or substract the data
# Ratios are not meaningful.
# for example Temperature in Celsius or Fahrenheit: 30°C, 40°C (The difference is meaningful, but 0°C doesn’t mean there is no temperature).
#
# Ratio Data
# Definition: Data that has all the properties of interval data, but also has a meaningful zero point.
# Characteristics:
# Can be added, subtracted, multiplied, or divided.
# Ratios are meaningful.
# Example:
# Weight: 0 kg, 50 kg, 100 kg (0 kg means no weight).

# %% [raw]
# Q6. Why is it important to understand the level of measurement when analyzing data? Provide an
# example to illustrate your answer.

# %% [raw]
# Understanding the level of measurement (nominal, ordinal, interval, ratio) is crucial because it determines the statistical methods that can be used. For example, nominal data (ex- gender) can only be analyzed with frequencies, while ordinal data (ex- satisfaction ratings) can be analyzed using the median or mode, but not the mean. Interval and ratio data (ex- temperature, income) allow for advanced calculations like mean and standard deviation. Misunderstanding the level of measurement can lead to incorrect analyses and conclusions, such as treating ordinal data as interval data and assuming equal differences between ratings.

# %% [raw]
# Q7. How nominal data type is different from ordinal data type.

# %% [raw]
# Both the nominal and ordinal comes under quantitative data because it is categorical where as the ordinal has one feature that distinguish from nominal is it can be orderd for example a company takes a ratings from the customer by giving four options Good,bad,avarage they can be ordered based on rating but,it cant be done in nominal for that case

# %% [raw]
# Q8. Which type of plot can be used to display data in terms of range?

# %% [raw]
# To display data in terms of a range, a box plot is commonly used.
#
# A box plot shows the distribution of a dataset based on five summary statistics:
#
# Minimum: The smallest data point excluding outliers.
# First Quartile (Q1): The median of the lower half of the dataset.
# Median (Q2): The middle data point.
# Third Quartile (Q3): The median of the upper half of the dataset.
# Maximum: The largest data point excluding outliers.

# %% [markdown]
# Q9. Describe the difference between descriptive and inferential statistics. Give an example of each
# type of statistics and explain how they are used.

# %% [raw]
# Descriptive and inferential statistics are two key branches of statistics used to analyze data, but they serve different purposes.
#
# Descriptive statistics involve summarizing or describing a dataset's main features, often using measures like mean, median, mode, standard deviation, and range. This type of statistics does not make predictions or generalizations about a population but rather provides a snapshot of the data.
#
# Example: Suppose a school wants to understand the average score of students in a math test. The mean score of 80 from a class of 50 students is a descriptive statistic because it simply describes the data collected from that specific group.
#
# Inferential statistics, on the other hand, involves making inferences or predictions about a population based on a sample of data. It uses probability theory to generalize findings from the sample to the larger population.
#
# For example a researcher surveys a sample of 200 people to estimate the average income of the entire population of 10,000 people. The findings from the sample are used to infer the income of the entire population, making inferential statistics useful for making predictions or testing hypotheses.

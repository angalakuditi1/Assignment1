# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from warnings import filterwarnings
filterwarnings('ignore')
import seaborn as sns

# %%
nw = pd.read_excel(r'C:\Users\benha\Downloads\flight_price.xlsx')
nw.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
nw.shape
# Out:
# (10683, 11)

# %%
nw.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %%
nw['Price']
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10683, dtype: int64

# %%
plt.hist(nw['Price'],bins=7,edgecolor='yellow',color='black')
plt.xlabel('price')
plt.ylabel('frequency')
plt.title('price distribution')
# Out:
# Text(0.5, 1.0, 'price distribution')

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
nw['Price'].unique()
# Out:
# array([ 3897,  7662, 13882, ...,  9790, 12352, 12648], dtype=int64)

# %%
np.max(nw['Price'])
# Out:
# 79512

# %%
np.min(nw['Price'])
# Out:
# 1759

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
nw.groupby(nw['Airline'])

# %%
grp = [group["Price"].values for _, group in nw.groupby("Airline")]
plt.figure(figsize=(35,25))
plt.boxplot(grp,labels = nw['Airline'].unique())
plt.xlabel('Airline')
plt.ylabel('Price')
plt.title('the box plot for price of flights group by airlines')
plt.show()

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,20))
plt.boxplot(nw["Price"])
plt.xlabel("Price")
plt.title("Boxplot for Outlier Detection")
plt.show()

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?

# %%
nw['day']= nw['Date_of_Journey'].str[0]
nw['month']= nw['Date_of_Journey'].str[1]
nw['year']= nw['Date_of_Journey'].str[2]

# %%
nw.drop(columns = ['Date_of_Journey'],inplace=True)

# %%
nw['month'].max()
# Out:
# '9'

# %%
#here the maximum 9th month which is sepmber as the month most busiest month which has the peak travel season

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?

# %% [raw]
# Time Series Line Charts
#
# Flight Price vs. Booking Date (To analyze advance booking effects)
# Flight Price vs. Departure Date (To capture seasonal trends)
#
# Box Plots
#
# Flight Price by Cabin Class (To compare price distributions across classes)
# Flight Price by Airline (To show variations across different airlines)
#
# Heatmaps
#
# Day of the Week vs. Price (To show the best/worst days to book flights)
# Month vs. Price (To highlight seasonal variations)
# Scatter Plots
#
# #these are some visulizations that can be used to analyze and find the patterns

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?

# %% [raw]
# To analyze flight prices, I would first examine key factors like booking date, travel date, route (origin & destination), airline, travel class (Economy, Business, First Class), number of stops, departure time, and demand trends. Prices often change based on when the ticket is booked, seasonality, weekdays vs. weekends, and competition on a route.
#
# I would clean the dataset by handling missing values and converting text data (like airline names) into numbers. Using graphs, I would check how prices vary for different airlines, routes, and seasons. A correlation heatmap would show which factors impact prices the most.
#
# For deeper insights, I would use machine learning models like Linear Regression or Random Forest to predict flight prices based on these factors. This helps in understanding which elements have the highest influence on pricing.

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
kew=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
kew.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
kew.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
kew.dropna(inplace=True)

# %%
kew.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
kew.shape
#there are 9360 rows and 13 coulmns after cleaning the data
# Out:
# (9360, 13)

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
kew['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
gr = [kew['Category'].values for _,group in  kew.groupby("Category")]

# %%
gpr = [kew['Category'].unique() for _,gropu in kew["Category"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 gpr = [kew['Category'].unique() for _,gropu in kew["Category"]]
#
# ValueError: too many values to unpack (expected 2)

# %%
plt.figure(figsize=(30,14))
sns.boxplot(x= 'Rating',y ='Category',data=kew)

# %%
#the ratings are definetly vary by category as from the box plots it is evident that most of the apps have the median average of 4 to 5 and  mnay have somany outliers too

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
nw.isnull().sum()

# %% [raw]
# Missing values can negatively impact a model’s performance by introducing bias, reducing accuracy, and distorting predictions. If missing values are ignored, models may misinterpret patterns, leading to incorrect conclusions. In supervised learning, missing target values hinder training, while missing features reduce the model’s ability to generalize. Methods like mean imputation, forward filling, or predictive imputation can mitigate these effects but may introduce additional bias. Incomplete data can also affect correlation and statistical significance. Advanced models like decision trees handle missing values better, but deep learning models often require imputation or special handling to prevent performance degradation.

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
kew=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
kew.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
kew['Size']=kew['Size'].str.replace('M','00')
kew['Size']=kew['Size'].str.replace('k','0')
kew['Size']=kew['Size'].str.replace('Varies with device','0')

# %%
Kew['Size'].unique()

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=new,x="Rating",y="Size",palette="viridis",alpha=0.5)
plt.show()

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
kew['Price'] = kew['Price'].str.replace('Everyone','0')

# %%
kew = pd.DataFrame(kew)

# %%
kew['Price'] = kew['Price'].str.replace('$','0')

# %%
kew['Price'].unique()
# Out:
# array(['0', '04.99', '03.99', '06.99', '01.49', '02.99', '07.99', '05.99',
#        '03.49', '01.99', '09.99', '07.49', '00.99', '09.00', '05.49',
#        '010.00', '024.99', '011.99', '079.99', '016.99', '014.99',
#        '01.00', '029.99', '012.99', '02.49', '010.99', '01.50', '019.99',
#        '015.99', '033.99', '074.99', '039.99', '03.95', '04.49', '01.70',
#        '08.99', '02.00', '03.88', '025.99', '0399.99', '017.99',
#        '0400.00', '03.02', '01.76', '04.84', '04.77', '01.61', '02.50',
#        '01.59', '06.49', '01.29', '05.00', '013.99', '0299.99', '0379.99',
#        '037.99', '018.99', '0389.99', '019.90', '08.49', '01.75',
#        '014.00', '04.85', '046.99', '0109.99', '0154.99', '03.08',
#        '02.59', '04.80', '01.96', '019.40', '03.90', '04.59', '015.46',
#        '03.04', '04.29', '02.60', '03.28', '04.60', '028.99', '02.95',
#        '02.90', '01.97', '0200.00', '089.99', '02.56', '030.99', '03.61',
# ...

# %%
kew['Price'] = pd.to_numeric(kew['Price'], errors='coerce')

# %%
kew.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159   19M      10,000+  Free    0.0       Everyone
# 1     967   14M     500,000+  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644   25M  50,000,000+  Free    0.0           Teen
# 4     967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
pew = kew.groupby('App',as_index = False)['Price'].mean()

# %%
kew.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159   19M      10,000+  Free    0.0       Everyone
# 1     967   14M     500,000+  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644   25M  50,000,000+  Free    0.0           Teen
# 4     967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
sns.barplot(x='App',y='Price',data=pew,palette='viridis')
plt.show()

# %%
plt.figure(figsize=(26,10))
sns.barplot(x=kew['App'],y=['Price'],data=pew,palette='viridis')
plt.show()
plt.show()

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
kew['Installs'] = kew['Installs'].str.replace('+','0')
kew['Installs'] = kew['Installs'].str.replace('Free','0')

# %%
kew['Installs'].unique()
# Out:
# array(['10,0000', '500,0000', '5,000,0000', '50,000,0000', '100,0000',
#        '50,0000', '1,000,0000', '10,000,0000', '5,0000', '100,000,0000',
#        '1,000,000,0000', '1,0000', '500,000,0000', '500', '1000', '5000',
#        '100', '10', '50', '00', '0'], dtype=object)

# %%
kew['Installs'] = pd.to_numeric(kew['Installs'].str.replace(',', ''), errors='coerce')

# %%
kew['Installs'].unique()
# Out:
# array([     100000,     5000000,    50000000,   500000000,     1000000,
#             500000,    10000000,   100000000,       50000,  1000000000,
#        10000000000,       10000,  5000000000,         500,        1000,
#               5000,         100,          10,          50,           0],
#       dtype=int64)

# %%
t10 = kew.nlargest(10,'Installs')

# %%
t10.sort_values(by='Installs', ascending=False)
# Out:
#                                           App             Category  Rating  \
# 152                         Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335  Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                        WhatsApp Messenger        COMMUNICATION     4.4
# 338              Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                     Gmail        COMMUNICATION     4.3
# 341                                  Hangouts        COMMUNICATION     4.0
# 381                        WhatsApp Messenger        COMMUNICATION     4.4
# 382  Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 386                                  Hangouts        COMMUNICATION     4.0
# 391             Skype - free IM & video calls        COMMUNICATION     4.1
#
#       Reviews                Size     Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %% [raw]
# To identify the most popular app categories, I would analyze a Google Playstore dataset using key features like Category, Installs, Ratings, and Reviews.
#
# Approach:
# Data Cleaning & Preprocessing:
# Remove duplicates, handle missing values, and convert Installs and Size to numeric formats.
#
# Feature Analysis:
# Category Popularity: Count the number of apps per category and analyze total installs and reviews.
#
# User Engagement: Compute average Rating and review count per category.
# Competitor Analysis: Identify saturated and niche categories.
#
# Recommendation:
# I would suggest categories with high installs, good ratings, and lower competition to maximize success.

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?

# %% [raw]
# To identify the most successful app developers from the Google Play Store dataset, we should analyze key metrics:
#
# Rating: Indicates user satisfaction and app quality.
# Reviews: Higher review counts suggest greater user engagement.
# Installs: Reflects app popularity and market reach.
# Price: Differentiates free vs. paid apps and their impact on success.
# Category & Genres: Identifies high-performing niches.
# Last Updated: Frequent updates indicate active development and better user retention.
#
# Visualizations to Use
# Bar Charts: Compare average ratings and installs across categories.
# Scatter Plots: Analyze the relationship between ratings and reviews.
# Box Plots: Compare revenue potential between free and paid apps.
# Heatmaps: Show correlations between features like rating, installs, and price.

# %% [raw]
# To determine the best time to launch a new app, we should analyze:
#
# Last Updated: Identifies trends in successful app launches.
# Installs & Reviews Over Time: Reveals peak user engagement periods.
# Category Trends: Shows which app genres perform best seasonally.
#
# Visualizations to Use
# Time Series Charts: Track installs and reviews over months.
# Heatmaps: Show seasonal trends in app performance.
# Bar Charts: Compare successful launch periods by category.

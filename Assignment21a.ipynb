# %% [markdown]
# Q1: What are missing values in a dataset? Why is it essential to handle missing values? Name some
# algorithms that are not affected by missing values.

# %% [raw]
# Missing values in a dataset occur when no data is recorded for one or more attributes in some observations. This can happen due to various reasons, such as data entry errors, system failures, or respondents skipping questions in surveys.
#
# Missing data can lead to incorrect statistical inferences and biased conclusions.
# Machine learning models may perform poorly if missing values are not handled properly.
# Simply removing rows with missing values can result in losing valuable information.
# Many machine learning models, such as logistic regression and decision trees, require complete datasets for training.
# Algorithms Not Affected by Missing Values
# Some machine learning algorithms can handle missing values inherently, including:
#
# K-Nearest Neighbors (KNN) – Can compute distances using available features.
# Random Forest – Can work with missing values by using surrogate splits.
# XGBoost – Automatically handles missing values by learning optimal imputation strategies.
# Naïve Bayes – Works well even with missing data by using probability-based assumptions.

# %% [markdown]
# Q2: List down techniques used to handle missing data. Give an example of each with python code.

# %%
#There are techniques that are helpful in help in missing values
#Removing Missing Values If missing values are few, dropping them might be a good approach.

import pandas as pd

data = {'Name': ['Arjun', 'Benhar', 'Cheta', 'Dravid'],
        'Age': [25, None, 30, 22]}

ne = pd.DataFrame(data)

drp = ne.dropna()
drp

#Filling Missing Values with a Constant
ne_fil = ne.fillna({'Age': 0})
print(ne_fil)
# Out:
#      Name   Age
# 0   Arjun  25.0
# 1  Benhar   0.0
# 2   Cheta  30.0
# 3  Dravid  22.0

# %% [markdown]
# Q3: Explain the imbalanced data. What will happen if imbalanced data is not handled?

# %% [raw]
# Imbalanced data occurs when one class significantly outnumbers another, as seen in fraud detection or medical diagnosis. If left unaddressed, machine learning models become biased toward the majority class, leading to poor predictions. A model may achieve high accuracy by predicting the dominant class but fail to detect critical minority cases.
#
# Consequences:
# High accuracy, low effectiveness (e.g., missing fraud cases).
# False negatives (e.g., undetected diseases).
# Misleading evaluation metrics (accuracy alone is unreliable).
# Solutions:
# Handling imbalance involves oversampling (SMOTE), undersampling, class weighting, or anomaly detection to improve model fairness and reliability.

# %% [markdown]
# Q4: What are Up-sampling and Down-sampling? Explain with an example when up-sampling and down-
# sampling are required.

# %% [raw]
# Up-sampling and down-sampling are techniques used to balance imbalanced datasets in machine learning.
#
# Up-sampling increases the minority class by duplicating existing data or generating synthetic samples (e.g., SMOTE). It is useful when the dataset has fewer instances of a particular class, ensuring the model learns patterns effectively.
#
# Down-sampling reduces the majority class by randomly removing instances, preventing the model from being biased toward dominant classes.
#
# Example: In fraud detection, where fraudulent transactions are rare, up-sampling helps balance the dataset. In spam detection, if non-spam emails dominate, down-sampling ensures equal representation, improving model performance.

# %% [markdown]
# Q5: What is data Augmentation? Explain SMOTE.

# %% [raw]
# Data Augmentation is a technique used to expand a dataset by creating modified versions of existing data, helping improve model accuracy and prevent overfitting. It is widely used in images (rotations, flips), text (synonym replacement), and tabular data (synthetic data generation).
#
# SMOTE (Synthetic Minority Over-sampling Technique) is a popular method for handling imbalanced datasets. Instead of simply duplicating minority class samples, SMOTE generates synthetic data points by analyzing relationships between existing minority samples. It selects a data point, finds its nearest neighbors, and creates new samples along the line connecting them.
#
# SMOTE enhances classification performance by ensuring the model learns patterns from a balanced dataset. However, it may create unrealistic samples if the minority class is highly underrepresented. Despite its limitations, SMOTE is widely used in fraud detection, medical diagnosis, and other applications where class imbalance affects predictive accuracy.

# %% [markdown]
# Q6: What are outliers in a dataset? Why is it essential to handle outliers?

# %% [raw]
# Outliers are data points that deviate significantly from the rest of the dataset. They can result from measurement errors, data entry mistakes, or genuine variability in data. Outliers can be identified using statistical methods such as the Z-score, IQR (Interquartile Range), or visualization techniques like box plots and scatter plots.
#
# Handling outliers is crucial because they can skew statistical analyses, leading to misleading conclusions. In machine learning, outliers can impact model accuracy by distorting patterns in the data. For example, in regression, extreme values can disproportionately influence the model, reducing its predictive performance.
#
# To handle outliers, analysts can remove them, transform the data (e.g., log transformation), or use robust statistical methods that minimize their impact. However, it's essential to analyze whether an outlier is an error or a meaningful data point before deciding on a treatment approach, ensuring data integrity and accurate analysis.

# %% [markdown]
# Q7: You are working on a project that requires analyzing customer data. However, you notice that some of
# the data is missing. What are some techniques you can use to handle the missing data in your analysis?

# %% [raw]
# Handling missing data is crucial for accurate analysis. Here are some techniques:
#
# Removal: If only a few records have missing values, you can remove those rows or columns to prevent bias. However, this may lead to data loss.
# Imputation: Replace missing values with meaningful estimates:
# Mean/Median Mode: Use the mean for numerical data, the median for skewed data, and the mode for categorical data.
# Forward/Backward Fill: In time-series data, propagate previous or next values.
# K-Nearest Neighbors (KNN): Predict missing values based on similar data points.
# Indicator Variables: Create a new column indicating missing data to help models learn from patterns.
# Predictive Modeling: Use regression or machine learning models to predict missing values.
# Ignoring : Algorithms like decision trees handle missing data naturally.
# Choosing the right technique depends on the dataset size, type, and the impact of missing values.

# %% [markdown]
# Q8: You are working with a large dataset and find that a small percentage of the data is missing. What are some strategies you can use to determine if the missing data is missing at random or if there is a pattern to the missing data?

# %% [raw]
# To check if missing data is random or follows a pattern, follow these steps:
#
# Identify Missing Data – Check which columns have missing values and their percentage.
# Use a Heatmap – A heatmap visually highlights missing values. If they cluster, they may not be random.
# Check Relationships – Compare missing data with other columns. If certain groups (e.g., young people) have more missing values, there’s a pattern.
# Look for Correlation – If missing values in one column align with high/low values in another, they are related.

# %% [markdown]
# Q9: Suppose you are working on a medical diagnosis project and find that the majority of patients in the
# dataset do not have the condition of interest, while a small percentage do. What are some strategies you
# can use to evaluate the performance of your machine learning model on this imbalanced dataset?

# %% [raw]
# In that case the data is imbalance infact so, i think Applying resampling techniques such as SMOTE (Synthetic Minority Over-sampling Technique) to generate synthetic minority samples or undersampling to reduce majority class bias

# %% [markdown]
# Q10: When attempting to estimate customer satisfaction for a project, you discover that the dataset is
# unbalanced, with the bulk of customers reporting being satisfied. What methods can you employ to
# balance the dataset and down-sample the majority class?

# %% [raw]
# To balance an unbalanced dataset where most customers report satisfaction, you can use down-sampling techniques to reduce the majority class while maintaining important patterns. Here are key methods:
#
# Random Down-Sampling: Randomly remove instances from the majority class until it matches the minority class. However, this may lead to information loss.
#
# Cluster-Based Sampling: Use clustering (e.g., K-Means) to group similar majority-class samples and select representative points to maintain diversity.
#
# Tomek Links Removal: Identify and remove closely paired majority-class samples near the decision boundary, enhancing class separability.
#
# NearMiss Algorithm: Select majority-class samples closest to the minority class, improving balance while preserving decision boundaries.
#
# Stratified Sampling: Ensure a proportional but reduced representation of the majority class while keeping statistical distribution intact.

# %% [markdown]
# Q11: You discover that the dataset is unbalanced with a low percentage of occurrences while working on a
# project that requires you to estimate the occurrence of a rare event. What methods can you employ to
# balance the dataset and up-sample the minority class?

# %% [raw]
# To handle imbalanced datasets with rare events, use sampling techniques:
#
# 1. Oversampling:
# Random Oversampling: Duplicates minority samples.
# SMOTE: Creates synthetic minority samples.
# ADASYN: Generates more samples for harder-to-learn cases.
#
# 2. Undersampling:
# Random Undersampling: Removes majority samples.
# Cluster-Based Undersampling: Removes redundant samples.
# 3. Hybrid Methods:
# SMOTE + Tomek Links/ENN: Balances data while removing noise.
# 4. Cost-Sensitive Learning:
# Adjusts class weights to penalize misclassification.
# 5. Anomaly Detection:
# Useful for rare event prediction.

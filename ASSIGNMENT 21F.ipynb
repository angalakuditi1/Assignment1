# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %%
import numpy as np

study_time = np.array([2, 4, 6, 8, 10])
exam_scores = np.array([50, 60, 70, 80, 90])

corr = np.corrcoef(study_time,exam_scores)
new = corr[0,1]
print(f'the correlation coefficient is{new:.2f}')
# Out:
# the correlation coefficient is1.00

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.

# %%
import numpy as np
import scipy.stats as stats

sleep_hours = [6, 7, 5, 8, 6, 9, 4, 7, 5, 8]
job_satisfaction = [5, 6, 4, 8, 5, 9, 3, 6, 4, 7]

spearman_corr, p_value = stats.spearmanr(sleep_hours, job_satisfaction)

print(f"Spearman's Rank Correlation Coefficient: {spearman_corr:.3f}")
print(f"P-value: {p_value:.3f}")

if p_value < 0.05:
    print("The correlation is statistically significant.")
else:
    print("The correlation is not statistically significant.")
# Out:
# Spearman's Rank Correlation Coefficient: 0.997
# P-value: 0.000
# The correlation is statistically significant.

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.

# %%
import numpy as np
import scipy.stats as stats

np.random.seed(42)
hours_exercise = np.random.randint(1, 10, 50)  # Hours of exercise per week
bmi = np.random.uniform(18, 35, 50)  # BMI values


pearson_corr, pearson_p_value = stats.pearsonr(hours_exercise, bmi)
spearman_corr, spearman_p_value = stats.spearmanr(hours_exercise, bmi)

print(f"Pearson Correlation Coefficient: {pearson_corr:.4f}, p-value: {pearson_p_value:.4f}")
print(f"Spearman's Rank Correlation: {spearman_corr:.4f}, p-value: {spearman_p_value:.4f}")
# Out:
# Pearson Correlation Coefficient: -0.2359, p-value: 0.0991
# Spearman's Rank Correlation: -0.2394, p-value: 0.0941

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.

# %%
import numpy as np
import scipy.stats as stats

np.random.seed(42)  # For reproducibility
tv_hours = np.random.randint(1, 6, 50)  # Random TV hours between 1 to 5
physical_activity = np.random.randint(30, 120, 50)  # Physical activity in minutes

correlation_coefficient, p_value = stats.pearsonr(tv_hours, physical_activity)

print(f"Pearson Correlation Coefficient: {correlation_coefficient:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Pearson Correlation Coefficient: -0.0363
# P-value: 0.8022

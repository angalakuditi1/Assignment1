# %% [markdown]
# Q1. What is a database? Differentiate between SQL and NoSQL databases.
#
# A database is an organized collection of data that is stored and managed in digitally . It allows users to store, retrieve, and manipulate data efficiently. Databases are commonly managed by software known as Database Management Systems.
#
# SQL is type of database where the data is stored in tabular format and SQL databases are best for structured, relational data.
# NoSQL databases or more of unstructured database.NoSQL databases excel with large-scale, unstructured, or rapidly changing data.

# %% [markdown]
# Q2. What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.
#
# DDL stands for Data Definition Language, which is a subset of SQL . It is used to define and manage the structure of database objects such as tables, schemas, indexes, etc. DDL commands directly affect the database schema and are typically used for tasks like creating, modifying, or deleting database structures.
#
# Each CREATE,DROP,ALTER AND TRUNCATE are the commands of ddl which have specific functionality where they work towards defining and  structuring  the database.

# %% [markdown]
# CREATE TABLE Employees (
#     EmployeeID INT PRIMARY KEY,
#     FirstName VARCHAR(50),
#     LastName VARCHAR(50),
#     Age INT
# );
#
#
# ALTER TABLE Employees
# ADD Email VARCHAR(100)
#
# DROP TABLE Employees;
# TRUNCATE TABLE Employees;
# ;

# %% [markdown]
# Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.
#
# DML (Data Manipulation Language) is a subset of SQL (Structured Query Language) used for managing and modifying data within a database. It includes the commands INSERT, UPDATE, and DELETE, which allow you to add, modify, and remove data in the database tables.
#
#
# The INSERT statement is used to add new rows of data to a table.
# INSERT INTO Employees (EmployeeID, FirstName, LastName, Age)
# VALUES (112, 'vinay', 'ben', 28);
#
# The UPDATE statement is used to modify existing records in a table. we  can update one or more columns in a single query.
# UPDATE Employees
# SET Age = 30
# WHERE EmployeeID = 112;
#
#
# The DELETE statement is used to remove one or more records from a table.
# DELETE FROM Employees
# WHERE EmployeeID = 112;

# %% [markdown]
# Q4. What is DQL? Explain SELECT with an example.
#
# DQL stands for Data Query Language, which is a subset of SQL used to query or retrieve data from a database. The primary DQL command is SELECT, which allows to select and retrieve data from one or more tables in a database.
#
# The SELECT statement is used to query the database and retrieve specific data. we can select entire tables, specific columns.
#
# keeping the abouve example SELECT * FROM Employees ;

# %% [markdown]
# Q5. Explain Primary Key and Foreign Key.
#
# A Primary Key is a field  that uniquely identifies each record in a table. It ensures that no two rows in the table can have the same value in the primary key column
#
# A Foreign Key is a column  in one table that links to the Primary Key of another table. It is used to establish and enforce a link between the data in two tables.

# %% [markdown]
# Q6. Write a python code to connect MySQL to python. Explain the cursor() and execute() method.

# %% [markdown]
# pip install mysql-connector
#
# import mysql.connector
#
# conn = mysql.connector.connect(
#     host="your_host",
#     user="your_username",
#     password="your_password",
#     database="your_database"
# )
#
# cursor = conn.cursor()
#
# cursor.execute("SELECT * FROM your_table")
#
# results = cursor.fetchall()
# for row in results:
#     print(row)
#
# cursor.close()
# conn.close()
#
#
# The cursor() method creates a cursor object. The cursor is used to interact with the database, execute SQL queries, and fetch the results.
#
# The execute() method is used to execute a single SQL query on the database.

# %% [markdown]
# Q7. Give the order of execution of SQL clauses in an SQL query.

# %% [markdown]
# FROM  ,JOIN  ,ON ,WHERE ,GROUP BY ,SELECT ,ORDER BY ,LIMIT / OFFSET
# This sequence ensures that SQL handles the filtering, sorting, and grouping in the right order
